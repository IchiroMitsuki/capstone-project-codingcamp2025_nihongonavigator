# %%
import pandas as pd

# %%
df_RevKanjistudy_clean = pd.read_csv(r"C:\Latihan_Python\casptone-project-dicoding_nihongonavigator\Preprocessesedtext\review_kanjistudy_processedtext.csv")

# %%
feature_keywords = {
    'kotoba': ['kosakata', 'vocab', 'kata', 'kotoba', 'kosa kata', 'kosa kt', 'kosakt'],
    'bunpou': ['grammar', 'tatabahasa', 'bunpou', 'tata bahasa', 'bunpo', 'tata bhs', 'tt bhs', 'pola kalimat', 'struktur kalimat', 'susunan kalimat', 'kalimat'],
    'kanji': ['kanji', 'huruf jepang', 'hrf jpng', 'tulisan jepang', 'karakter jepang', 'radikal']
}

def detect_features(text, keyword_dict):
    detected = set()
    for label, keywords in keyword_dict.items():
        for word in keywords:
            if word in text.lower():
                detected.add(label)
    return ','.join(sorted(detected))

# Terapkan ke data Mazii
df_RevKanjistudy_clean['fitur_terdeteksi'] = df_RevKanjistudy_clean['text_final_stemmed'].apply(
    lambda x: detect_features(str(x), feature_keywords) if isinstance(x, str) else ''
)

# Filter hanya ulasan yang punya fitur (agar bisa lanjut ke tahap sentimen)
df_RevKanjistudy_clean_with_features = df_RevKanjistudy_clean[df_RevKanjistudy_clean['fitur_terdeteksi'] != '']

# %%
df_RevKanjistudy_clean_with_features.head()
# Out:
#                                               Review  \
# 0  Sangat membantu untuk memahami kanji, desain y...
# 1  aplikasi ini membantu banget buat yang otodida...
# 3  kanji lengkap, setiap kanji, radikal dan kompo...
# 6  Pokoknya Sangat cocok sekali bagi penghafal hu...
# 7  sangat mudah di pahami. kanjinya dibagi persep...
#
#                                           text_clean  \
# 0  Sangat membantu untuk memahami kanji desain ya...
# 1  aplikasi ini membantu banget buat yang otodida...
# 3  kanji lengkap setiap kanji radikal dan kompone...
# 6  Pokoknya Sangat cocok sekali bagi penghafal hu...
# 7  sangat mudah di pahami kanjinya dibagi persepu...
#
#                                 text_casefoldingText  \
# 0  sangat membantu untuk memahami kanji desain ya...
# 1  aplikasi ini membantu banget buat yang otodida...
# 3  kanji lengkap setiap kanji radikal dan kompone...
# 6  pokoknya sangat cocok sekali bagi penghafal hu...
# ...

# %%
df_RevKanjistudy_clean_with_features.to_csv(r"C:\Latihan_Python\casptone-project-dicoding_nihongonavigator\preprocessed_with_features\review_kanjistudy_processedtext_with_features.csv", index=False)
