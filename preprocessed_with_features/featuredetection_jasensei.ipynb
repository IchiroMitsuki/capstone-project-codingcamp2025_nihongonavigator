# %%
import pandas as pd

# %%
df_RevJAsensei_clean = pd.read_csv(r"C:\Latihan_Python\casptone-project-dicoding_nihongonavigator\Preprocessesedtext\review_jasensei_processedtext.csv")

# %%
feature_keywords = {
    'kotoba': ['kosakata', 'vocab', 'kata', 'kotoba', 'kosa kata', 'kosa kt', 'kosakt'],
    'bunpou': ['grammar', 'tatabahasa', 'bunpou', 'tata bahasa', 'bunpo', 'tata bhs', 'tt bhs', 'pola kalimat', 'struktur kalimat', 'susunan kalimat', 'kalimat'],
    'kanji': ['kanji', 'huruf jepang', 'hrf jpng', 'tulisan jepang', 'karakter jepang', 'radikal']
}

def detect_features(text, keyword_dict):
    detected = set()
    for label, keywords in keyword_dict.items():
        for word in keywords:
            if word in text.lower():
                detected.add(label)
    return ','.join(sorted(detected))

# Terapkan ke data Mazii
df_RevJAsensei_clean['fitur_terdeteksi'] = df_RevJAsensei_clean['text_final_stemmed'].apply(
    lambda x: detect_features(str(x), feature_keywords) if isinstance(x, str) else ''
)

# Filter hanya ulasan yang punya fitur (agar bisa lanjut ke tahap sentimen)
df_RevJAsensei_clean_with_features = df_RevJAsensei_clean[df_RevJAsensei_clean['fitur_terdeteksi'] != '']

# %%
df_RevJAsensei_clean_with_features.head()
# Out:
#                                                Review  \
# 5   Materi sangat bervariasi dalam satu aplikasi, ...
# 6   Pertama, versi bahasa Indonesianya baku tapi g...
# 9   Aku sangat suka dan penjelasan dari contoh kal...
# 10  Fiturnya sangat lengkap mulai dari kanji, list...
# 28  Untuk penjelasan "tata bahasa", masih belum se...
#
#                                            text_clean  \
# 5   Materi sangat bervariasi dalam satu aplikasi m...
# 6   Pertama versi bahasa Indonesianya baku tapi ga...
# 9   Aku sangat suka dan penjelasan dari contoh kal...
# 10  Fiturnya sangat lengkap mulai dari kanji liste...
# 28  Untuk penjelasan tata bahasa masih belum semua...
#
#                                  text_casefoldingText  \
# 5   materi sangat bervariasi dalam satu aplikasi m...
# 6   pertama versi bahasa indonesianya baku tapi ga...
# 9   aku sangat suka dan penjelasan dari contoh kal...
# 10  fiturnya sangat lengkap mulai dari kanji liste...
# ...

# %%
df_RevJAsensei_clean_with_features.to_csv(r"C:\Latihan_Python\casptone-project-dicoding_nihongonavigator\preprocessed_with_features\review_jasensei_processedtext_with_features.csv", index=False)
