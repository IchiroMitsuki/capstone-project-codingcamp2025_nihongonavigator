# %%
import pandas as pd

# %%
df_RevObenkyo_clean = pd.read_csv(r"C:\Latihan_Python\casptone-project-dicoding_nihongonavigator\Preprocessesedtext\review_obenkyo_processedtext.csv")

# %%
feature_keywords = {
    'kotoba': ['kosakata', 'vocab', 'kata', 'kotoba', 'kosa kata', 'kosa kt', 'kosakt'],
    'bunpou': ['grammar', 'tatabahasa', 'bunpou', 'tata bahasa', 'bunpo', 'tata bhs', 'tt bhs', 'pola kalimat', 'struktur kalimat', 'susunan kalimat', 'kalimat'],
    'kanji': ['kanji', 'huruf jepang', 'hrf jpng', 'tulisan jepang', 'karakter jepang', 'radikal']
}

def detect_features(text, keyword_dict):
    detected = set()
    for label, keywords in keyword_dict.items():
        for word in keywords:
            if word in text.lower():
                detected.add(label)
    return ','.join(sorted(detected))

# Terapkan ke data Mazii
df_RevObenkyo_clean['fitur_terdeteksi'] = df_RevObenkyo_clean['text_final_stemmed'].apply(
    lambda x: detect_features(str(x), feature_keywords) if isinstance(x, str) else ''
)

# Filter hanya ulasan yang punya fitur (agar bisa lanjut ke tahap sentimen)
df_RevObenkyo_clean_with_features = df_RevObenkyo_clean[df_RevObenkyo_clean['fitur_terdeteksi'] != '']

# %%
df_RevObenkyo_clean_with_features.head()
# Out:
#                                                Review  \
# 0   Overall sudah bagus semua nya. Kurang diterjem...
# 1   Sangat membantu, banyak sekali pilihan quiz mu...
# 6   Applikasi ini bagus untuk belajar dr awal bang...
# 8   Tolong dong ada pilihan bahasa Indonesia nya j...
# 12  Sangat tidak merekomendasikan aplikasi ini, sa...
#
#                                            text_clean  \
# 0   Overall sudah bagus semua nya Kurang diterjema...
# 1   Sangat membantu banyak sekali pilihan quiz mul...
# 6   Applikasi ini bagus untuk belajar dr awal bang...
# 8   Tolong dong ada pilihan bahasa Indonesia nya j...
# 12  Sangat tidak merekomendasikan aplikasi ini say...
#
#                                  text_casefoldingText  \
# 0   overall sudah bagus semua nya kurang diterjema...
# 1   sangat membantu banyak sekali pilihan quiz mul...
# 6   applikasi ini bagus untuk belajar dr awal bang...
# 8   tolong dong ada pilihan bahasa indonesia nya j...
# ...

# %%
df_RevObenkyo_clean_with_features.to_csv(r"C:\Latihan_Python\casptone-project-dicoding_nihongonavigator\preprocessed_with_features\review_obenkyo_processedtext_with_features.csv", index=False)
